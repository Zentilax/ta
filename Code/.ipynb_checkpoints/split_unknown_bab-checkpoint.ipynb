# %%
import os
import re
import csv
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Aqil Anhein\Desktop\TA\Peraturan Pemerintah\cleaned_txt\final_cleaned\extracted_legal_data.csv")
df
# Out:
#                                judul  \
# 0    PP_No_29-Tahun_2021_cleaned.txt
# 1    PP_No_29-Tahun_2021_cleaned.txt
# 2    PP_No_29-Tahun_2021_cleaned.txt
# 3    PP_No_29-Tahun_2021_cleaned.txt
# 4    PP_No_29-Tahun_2021_cleaned.txt
# ..                               ...
# 174  PP_No_29-Tahun_2021_cleaned.txt
# 175  PP_No_29-Tahun_2021_cleaned.txt
# 176  PP_No_29-Tahun_2021_cleaned.txt
# 177  PP_No_29-Tahun_2021_cleaned.txt
# 178  PP_No_29-Tahun_2021_cleaned.txt
#
#                                                    BAB      Pasal  \
# 0                                BAB I: KETENTUAN UMUM    PASAL 1
# 1                                BAB I: KETENTUAN UMUM    PASAL 2
# 2    BAB II: KEBIJAKAN DAN PENGENDALIAN EKSPOR DAN ...    PASAL 3
# 3    BAB II: KEBIJAKAN DAN PENGENDALIAN EKSPOR DAN ...    PASAL 4
# 4    BAB II: KEBIJAKAN DAN PENGENDALIAN EKSPOR DAN ...    PASAL 5
# ..                                                 ...        ...
# ...

# %%
def split_by_bab(df):
    df_known_bab = df[df['BAB'] != 'UNKNOWN'].reset_index(drop=True)
    df_unknown_bab = df[df['BAB'] == 'UNKNOWN'].reset_index(drop=True)
    return df_known_bab, df_unknown_bab

# %%
df_known, df_unknown = split_by_bab(df)

# %%
df_unknown = df_unknown.drop(columns=['BAB'])

# %%
df_unknown.to_csv(r'C:\Users\Aqil Anhein\Desktop\TA\Peraturan Pemerintah\cleaned_txt\final_cleaned\bab_cleaned\unknown_bab.csv', index=False, encoding='utf-8-sig')
df_known.to_csv(r'C:\Users\Aqil Anhein\Desktop\TA\Peraturan Pemerintah\cleaned_txt\final_cleaned\bab_cleaned\known_bab.csv', index=False, encoding='utf-8-sig')
