# %%
import os
import re
import csv
import pandas as pd

# %%
df_1 = pd.read_csv(r"C:\Users\Aqil Anhein\Desktop\TA\Peraturan Menteri\cleaned_txt\final_cleaned\bab_cleaned\unknown_bab.csv")
df_2 = pd.read_csv(r"C:\Users\Aqil Anhein\Desktop\TA\Peraturan Menteri\Perubahan 1\cleaned_txt\final_cleaned\bab_cleaned\unknown_bab.csv")
df_3 = pd.read_csv(r"C:\Users\Aqil Anhein\Desktop\TA\Peraturan Menteri\Perubahan 2\cleaned_txt\final_cleaned\bab_cleaned\unknown_bab.csv")
df_4 = pd.read_csv(r"C:\Users\Aqil Anhein\Desktop\TA\Peraturan Menteri\Perubahan 3\cleaned_txt\final_cleaned\bab_cleaned\unknown_bab.csv")
df_5 = pd.read_csv(r"C:\Users\Aqil Anhein\Desktop\TA\Peraturan Menteri\Perubahan 4\cleaned_txt\final_cleaned\bab_cleaned\unknown_bab.csv")

# %%
unknown_combined = pd.concat([df_1, df_2, df_3, df_4, df_5], ignore_index=True)
unknown_combined
# Out:
#                                                  judul     Pasal  \
# 0           PERMEN_BUMN_No_1147_Tahun_2017_cleaned.txt   PASAL 1
# 1           PERMEN_BUMN_No_1147_Tahun_2017_cleaned.txt   PASAL 2
# 2           PERMEN_BUMN_No_1147_Tahun_2017_cleaned.txt   PASAL 3
# 3           PERMEN_BUMN_No_1147_Tahun_2017_cleaned.txt   PASAL 4
# 4           PERMEN_BUMN_No_1147_Tahun_2017_cleaned.txt   PASAL 5
# ..                                                 ...       ...
# 99   PERMEN_BUMN_No_46_Tahun_2018_Dirubah_812_2021_...  PASAL 10
# 100  PERMEN_BUMN_No_812_Tahun_2021_Merubah_46_2018_...   PASAL 1
# 101  PERMEN_BUMN_No_812_Tahun_2021_Merubah_46_2018_...   PASAL 2
# 102  PERMEN_BUMN_No_812_Tahun_2021_Merubah_46_2018_...   PASAL 3
# 103  PERMEN_BUMN_No_812_Tahun_2021_Merubah_46_2018_...   PASAL 5
#
#                                                Content
# 0    Dalam Peraturan Menteri ini yang dimaksud deng...
# 1    Prinsip -prinsip yang harus diperhatikan dala ...
# ...

# %%
df_1 = pd.read_csv(r"C:\Users\Aqil Anhein\Desktop\TA\Peraturan Menteri\cleaned_txt\final_cleaned\bab_cleaned\known_bab.csv")
df_2 = pd.read_csv(r"C:\Users\Aqil Anhein\Desktop\TA\Peraturan Menteri\Perubahan 1\cleaned_txt\final_cleaned\bab_cleaned\known_bab.csv")
df_3 = pd.read_csv(r"C:\Users\Aqil Anhein\Desktop\TA\Peraturan Menteri\Perubahan 2\cleaned_txt\final_cleaned\bab_cleaned\known_bab.csv")
df_4 = pd.read_csv(r"C:\Users\Aqil Anhein\Desktop\TA\Peraturan Menteri\Perubahan 3\cleaned_txt\final_cleaned\bab_cleaned\known_bab.csv")
df_5 = pd.read_csv(r"C:\Users\Aqil Anhein\Desktop\TA\Peraturan Menteri\Perubahan 4\cleaned_txt\final_cleaned\bab_cleaned\known_bab.csv")

# %%
known_combined = pd.concat([df_1, df_2, df_3, df_4,df_5], ignore_index=True)
known_combined
# Out:
#                                                   judul  \
# 0              PERMEN_BUMN_No_12_Tahun_2022_cleaned.txt
# 1              PERMEN_BUMN_No_12_Tahun_2022_cleaned.txt
# 2              PERMEN_BUMN_No_12_Tahun_2022_cleaned.txt
# 3              PERMEN_BUMN_No_12_Tahun_2022_cleaned.txt
# 4              PERMEN_BUMN_No_12_Tahun_2022_cleaned.txt
# ...                                                 ...
# 1349  PERMEN_BUMN_No_961_Tahun_2022_Merubah_958_2021...
# 1350  PERMEN_BUMN_No_961_Tahun_2022_Merubah_958_2021...
# 1351  PERMEN_BUMN_No_961_Tahun_2022_Merubah_958_2021...
# 1352  PERMEN_BUMN_No_961_Tahun_2022_Merubah_958_2021...
# 1353  PERMEN_BUMN_No_961_Tahun_2022_Merubah_958_2021...
#
#                                                BAB     Pasal  \
# 0                            BAB I: KETENTUAN UMUM   PASAL 1
# 1                            BAB I: KETENTUAN UMUM   PASAL 2
# 2                            BAB I: KETENTUAN UMUM   PASAL 3
# ...

# %%
unknown_combined.to_csv(r'C:\Users\Aqil Anhein\Desktop\TA\Peraturan Menteri\data\unknown_combined.csv', index=False, encoding='utf-8-sig')
known_combined.to_csv(r'C:\Users\Aqil Anhein\Desktop\TA\Peraturan Menteri\data\known_combined.csv', index=False, encoding='utf-8-sig')
